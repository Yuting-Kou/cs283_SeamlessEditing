# %%
import numpy as np
import cv2
from scipy.sparse import diags
from scipy.sparse import dia_matrix
import scipy
import matplotlib.pyplot as plt
from scipy.sparse.linalg import spsolve, cg
from numba import jit

# %%
import os
os.getcwd()
os.chdir("./cs283_SeamlessEditing/")

# %%
from src.poisson_solver import *
from src.equation import *

# %%
paths = "./test/"
destination = "swan.jpg"
source = "kyt.jpg"
save = "mask.png"

# %%
source = plt.imread(paths + source)  # source=mp.image_g
destination = plt.imread(paths + destination)  # destination=mp.image_f

tx, ty = (-184, -158)
mask = plt.imread(paths + save)
mask[mask != 1] = 0
mask = mask[:,:,0]

# %%
test = Poisson_system(source=source, destination=destination, mask=mask, offset=[tx, ty])

# %%
A, b = test.get_Ab()

# %%
data = [np.array(it) for it in A.data]
rows = [np.array(it) for it in A.rows]
diag = A.diagonal()

# %%
from numba.typed import List

data_ = List()
[data_.append(x) for x in data];

rows_ = List()
[rows_.append(x) for x in rows];

# %%
omega = 1.8
x0 = np.zeros(b.shape)
x1 = sor_solver_jit(data_, rows_, diag, b, omega, x0)
# Out:
# 0 4560.303738839532
# 50 23.756801304186915
# 100 10.517877108584939
# 150 6.9586746217823015
# 200 5.361433580460134
# 243
# func:'sor_solver_jit' took: 67.2383 sec

# %%
omega = 1.8
x0 = test.g[test.mask == 1]
x2 = sor_solver_jit(data_, rows_, diag, b, omega, x0, 0.01)
# Out:
# 0 4333.884676015372
# 50 28.275073170734448
# 100 15.967215034295577
# 150 11.927077922241244
# 200 9.89442420670104
# 250 8.589432310977681
# 300 7.601647377016217
# 350 6.786682264516024
# 400 6.086360313256035
# 450 5.472360957679734
# 500 4.928160542805812
# 537
# func:'sor_solver_jit' took: 138.8774 sec

# %%
res = test.combine(x1)

# %%
from src.gradient_field import *

koko = Gradient_Field(source=source, destination=destination, mask=mask, offset=[tx, ty],  neighbor_ker=4)
A1, b1 = koko.get_v(method='dg')
# Out:
# Importing gradients: v=dg

# %%
plt.rcParams['figure.figsize'] = (12,5)
plt.subplot(1,2,1)
plt.imshow(test.combine(x1))

plt.subplot(1,2,2)
plt.imshow(test.combine(x2))

# %%
plt.rcParams['figure.figsize'] = (15,5)
plt.subplot(1,3,1)
plt.imshow(test.mask)

plt.subplot(1,3,2)
plt.imshow(test.g)

plt.subplot(1,3,3)
plt.imshow(test.f)
plt.tight_layout()
